# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy as sio
import networkx as nx
import csv
from collections import Counter
from itertools import combinations as cmb

# %%
# %matplotlib notebook

# %%
#source
acc_sce_ori = [0.8708, 0.9008333333333334, 0.9245, 0.9335, 0.9383333333333334, 0.9426666666666667, 0.946, 0.9471666666666667, 0.9491666666666667, 0.9505, 0.9518333333333333]

#target 1
acc_tar1_ori = [ 0.8658, 0.8746666666666667, 0.9278333333333333, 0.9373333333333334, 0.9425, 0.945, 0.949, 0.9523333333333334, 0.9535, 0.955, 0.958]
acc_tar1_transfer1 = [ 0.5995, 0.6243684210526316, 0.6714736842105263, 0.7021578947368421, 0.7303157894736843, 0.748578947368421, 0.7519473684210526, 0.7598421052631579, 0.7692105263157895, 0.7757368421052632, 0.7832105263157895]
acc_tar1_transfer2 = [ 0.6053, 0.6609444444444444, 0.7196666666666667, 0.7536666666666667, 0.798, 0.8095, 0.8161111111111111, 0.8266111111111111, 0.8347222222222223, 0.842, 0.8474444444444444]
acc_tar1_transfer3 = [ 0.6531, 0.70425, 0.7924375, 0.8358125, 0.852, 0.8621875, 0.8695, 0.8761875, 0.882375, 0.886375, 0.8895]
acc_tar1_transfer4 = [0.75, 0.8333, 0.8771, 0.8983, 0.9073, 0.9134, 0.9186, 0.9229, 0.9269, 0.9298, 0.9342]


# target 2
#acc_tar2_ori = [0.8256, 0.8657407407407407, 0.9016666666666666, 0.9162962962962963, 0.9268518518518518, 0.932962962962963, 0.9387037037037037, 0.9414814814814815, 0.9438888888888889, 0.9468518518518518, 0.9496296296296296]
#acc_tar2_transfer = [0.5593567251461988, 0.5385380116959064, 0.6192397660818714, 0.7287719298245614, 0.7575438596491229, 0.5522807017543859, 0.7821637426900585, 0.7871929824561403, 0.79046783625731, 0.7947953216374269]

# %%
#PLOT

# Number of restaurants that are equal  
fig = plt.figure()
plt.title( 'Retaining experiments on Logistic Regression baseline')
plt.xlabel("Number of Epochs")
plt.ylabel('Accuracy on the Development Set')

# similar
# plt.plot(top_list, top_list - np.array(difference_foodies_with_rank),'b', label='for foodies')
# plt.plot(top_list, top_list - np.array(difference_all_with_rank),color='darkorange', label='for all')

# different
#plt.plot(top_list,difference_foodies_with_rank,'b', label='for foodies')
#plt.plot(top_list,difference_all_with_rank,color='darkorange', label='for all')

# percentage similiar
plt.plot(range(len(acc_sce_ori)), acc_sce_ori, '.-k', label='source training set')
plt.plot(range(len(acc_tar1_ori)), acc_tar1_ori, '.-b', label='target transfer set (100% training data)')
plt.plot(range(len(acc_tar1_transfer)), acc_tar1_transfer4, '.-c', label='target transfer set (50% training data)')
plt.plot(range(len(acc_tar1_transfer)), acc_tar1_transfer3, '.-m', label='target transfer set (20% training data)')
plt.plot(range(len(acc_tar1_transfer)), acc_tar1_transfer2, '.-',color='darkorange', label='target transfer set (10% training data)')
plt.plot(range(len(acc_tar1_transfer)), acc_tar1_transfer1, '.-r', label='target transfer set (5% training data)')

#plt.plot(range(len(acc_tar2_ori)), acc_tar2_ori, 'b', label='training set')
#plt.plot(.range(len(acc_tar2_transfer)), acc_tar2_transfer, 'b', label='training set')

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="491.85185185185185">

# %%
fig.savefig('LogisticR.svg', bbox_inches='tight')
